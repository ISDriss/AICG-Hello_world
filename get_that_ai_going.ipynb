# %% [markdown]
# 1. Load Dataset
# 2. Define Parametrized Model
# 3. Instantiate Model
# 4. Instantiate Optimizer
# 5. Training/Eval Loop
#     1. Set Gradients to Zero
#     2. Compute out Estimation (Forward Pass)
#     3. Compute our Loss (Objective Function to Minimize)
#     4. Compute out Gradients (Backward Pass)
#     5. Update our Weights
#     6. Monitoring (Visualize Training Loss / Eval Loss)
# 6. Save our Weights
# 7. Export our Model for WebGPU

# %%
from typing import Callable
from tinygrad import Tensor, TinyJit
from tinygrad.nn.datasets import mnist
from tinygrad.nn.optim import Adam
from tinygrad.helpers import trange
import tinygrad.nn as nn

# %%
class Model:
    def __init__(self) : 
        self.layers: list[Callable[[Tensor], Tensor]] = [
            lambda x: x.flatten(1),
            nn.Linear(784, 512), Tensor.relu,
            nn.Linear(512, 512), Tensor.relu,
            nn.Linear(512, 10)
        ]

    def __call__(self, x: Tensor) -> Tensor:
        return x.sequential(self.layers)

# %%
X_train,Y_train, X_test, Y_test = mnist()
model = Model()
opt = Adam(nn.state.get_parameters(model))

# %%
@TinyJit
@Tensor.train()
def train_step() -> Tensor:
    opt.zero_grad()
    samples = Tensor.randint(512, high=int(X_train.shape[0]))
    loss = model(X_train[samples]).sparse_categorical_crossentropy(Y_train[samples]).backward()
    return loss.realize(*opt.schedule_step())

@TinyJit
def get_test_acc() -> Tensor:
    return model(X_test).argmax(axis=1) == (Y_test).mean() * 100

# %%
test_acc = float('nan')
for step in (t := trange(100)):
    loss = train_step().item
    if step % 10 == 9: test_acc = get_test_acc().item()
    t.set_description(f"loss: {loss:4.2f} test acc: {test_acc:4.2f}%")
# Out:
#   0%|                                                   | 0/100 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 3
#       1 test_acc = float('nan')
#       2 for step in (t := trange(100)):
# ----> 3     loss = train_step().item
#       4     if step % 10 == 9: test_acc = get_test_acc().item()
#       5     t.set_description(f"loss: {loss:4.2f} test acc: {test_acc:4.2f}%")
#
# File ~/GitProjects/AICG-B.A_BA/.venv/lib/python3.13/site-packages/tinygrad/engine/jit.py:276, in TinyJit.__call__(self, *args, **kwargs)
#     274   assert self.fxn is not None
#     275   with Context(BEAM=0 if getenv("IGNORE_JIT_FIRST_BEAM") else BEAM.value):
# --> 276     ret = self.fxn(*args, **kwargs)
#     277     if len(params:=get_parameters(ret)): Tensor.realize(params[0], *params[1:])
#     278 elif self.cnt == 1:
#     279   # jit capture
#
# File ~/.pyenv/versions/3.13.7/lib/python3.13/contextlib.py:85, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      82 @wraps(func)
#      83 def inner(*args, **kwds):
#      84     with self._recreate_cm():
# ---> 85         return func(*args, **kwds)
#
# Cell In[4], line 7, in train_step()
#       5 samples = Tensor.randint(512, high=int(X_train.shape[0]))
#       6 loss = model(X_train[samples]).sparse_categorical_crossentropy(Y_train[samples]).backward()
# ----> 7 return loss.realize(*opt.schedule_step())
#
# File ~/GitProjects/AICG-B.A_BA/.venv/lib/python3.13/site-packages/tinygrad/tensor.py:4432, in _metadata_wrapper.<locals>._wrapper(*args, **kwargs)
#    4429 else: caller = ""
#    4431 token = _METADATA.set(Metadata(name=fn.__name__, caller=caller))
# -> 4432 ret = fn(*args, **kwargs)
#    4433 _METADATA.set(token)
#    4434 return ret
#
# File ~/GitProjects/AICG-B.A_BA/.venv/lib/python3.13/site-packages/tinygrad/tensor.py:266, in Tensor.realize(self, do_update_stats, *lst)
#     264 def realize(self, *lst:Tensor, do_update_stats=True) -> Tensor:
#     265   """Triggers the computation needed to create these Tensor(s)."""
# --> 266   run_schedule(*self.schedule_with_vars(*lst), do_update_stats=do_update_stats)
#     267   return self
#
# File ~/GitProjects/AICG-B.A_BA/.venv/lib/python3.13/site-packages/tinygrad/engine/realize.py:195, in run_schedule(schedule, var_vals, do_update_stats)
#     194 def run_schedule(schedule:list[ScheduleItem], var_vals:dict[Variable, int]|None=None, do_update_stats=True):
# --> 195   for si, ei in lower_schedule(schedule):
#     196     if len(capturing) and CAPTURING: capturing[0].add(ei)
#     197     if VALIDATE_WITH_CPU and si.ast.op is Ops.SINK:
#     198       # copy in allocated buffers from the GPU
#
# File ~/GitProjects/AICG-B.A_BA/.venv/lib/python3.13/site-packages/tinygrad/engine/realize.py:188, in lower_schedule(schedule)
#     186   print("tensor operations:")
#     187   pprint.pprint(si.metadata, indent=2)
# --> 188 raise e
#
# File ~/GitProjects/AICG-B.A_BA/.venv/lib/python3.13/site-packages/tinygrad/engine/realize.py:182, in lower_schedule(schedule)
#     180 while len(schedule):
#     181   si = schedule.pop(0)
# --> 182   try: yield (si, lower_schedule_item(si))
#     183   except Exception as e:
#     184     if DEBUG >= 2:
#
# File ~/GitProjects/AICG-B.A_BA/.venv/lib/python3.13/site-packages/tinygrad/engine/realize.py:177, in lower_schedule_item(si)
#     176 def lower_schedule_item(si:ScheduleItem) -> ExecItem:
# --> 177   return ExecItem(*cast(tuple[Runner,list], si_lowerer.rewrite(si.ast, si.bufs)), si.metadata, si.fixedvars)
#
# File ~/GitProjects/AICG-B.A_BA/.venv/lib/python3.13/site-packages/tinygrad/uop/ops.py:769, in PatternMatcher.rewrite(self, uop, ctx)
#     767 for _,match,early_reject in self.pdict.get(uop.op, []):
#     768   if not early_reject.issubset(ler): continue
# --> 769   if (ret:=match(uop, ctx)) is not None and ret is not uop: return ret
#     770 return None
#
# File <string>:3, in compiled_match(uop, ctx)
#
# File ~/GitProjects/AICG-B.A_BA/.venv/lib/python3.13/site-packages/tinygrad/engine/realize.py:170, in <lambda>(ctx, sink)
#     166     return et
#     168 # NOTE: ctx is the buffers
#     169 si_lowerer = PatternMatcher([
# --> 170   (UPat(Ops.SINK, name="sink"), lambda ctx,sink: (runner:=get_runner(ctx[0].device, sink), [ctx[x] for x in runner.p.globals])),
#     171   (UPat(Ops.BUFFER_VIEW), lambda ctx: (ViewOp(ctx[0]), list(ctx))),
#     172   (UPat(Ops.COPY, name="copy"), lambda ctx,copy: ((BufferXfer(ctx[0].nbytes, ctx[0].device, ctx[1].device) \
#     173       if hasattr(Device[ctx[0].device].allocator, '_transfer') and all_same([x.device.split(":")[0] for x in ctx]) \
#     174       else BufferCopy(ctx[0].nbytes, ctx[0].device, ctx[1].device)), list(ctx))),
#     175 ])
#     176 def lower_schedule_item(si:ScheduleItem) -> ExecItem:
#     177   return ExecItem(*cast(tuple[Runner,list], si_lowerer.rewrite(si.ast, si.bufs)), si.metadata, si.fixedvars)
#
# File ~/GitProjects/AICG-B.A_BA/.venv/lib/python3.13/site-packages/tinygrad/engine/realize.py:138, in get_runner(device, ast)
#     136 else:
#     137   prg: ProgramSpec = get_program(ast, Device[device].renderer)
# --> 138   method_cache[ckey] = method_cache[bkey] = ret = CompiledRunner(replace(prg, device=device))
#     139 return ret
#
# File ~/GitProjects/AICG-B.A_BA/.venv/lib/python3.13/site-packages/tinygrad/engine/realize.py:69, in CompiledRunner.__init__(self, p, precompiled, prg)
#      67 else:
#      68   with cpu_profile(TracingKey(f"compile {p.name}", (p.function_name,), cat="compiler"), "TINY"):
# ---> 69     self.lib = Device[p.device].compiler.compile_cached(p.src)
#      70 if DEBUG >= 7: Device[p.device].compiler.disassemble(self.lib)
#      71 self._prg = Device[p.device].runtime(p.function_name, self.lib) if prg is None else prg
#
# File ~/GitProjects/AICG-B.A_BA/.venv/lib/python3.13/site-packages/tinygrad/device.py:271, in Compiler.compile_cached(self, src)
#     269 if self.cachekey is None or (lib := diskcache_get(self.cachekey, src)) is None:
#     270   assert not getenv("ASSERT_COMPILE"), f"tried to compile with ASSERT_COMPILE set\n{src}"
# --> 271   lib = self.compile(src)
#     272   if self.cachekey is not None: diskcache_put(self.cachekey, src, lib)
#     273 return lib
#
# File ~/GitProjects/AICG-B.A_BA/.venv/lib/python3.13/site-packages/tinygrad/runtime/ops_cpu.py:25, in ClangJITCompiler.compile(self, src)
#      23 args = [arch, f'--target={target}-none-unknown-elf', '-O2', '-fPIC', '-ffreestanding', '-fno-math-errno', '-nostdlib', '-fno-ident']
#      24 arch_args = ['-ffixed-x18'] if target == 'arm64' else []
# ---> 25 obj = subprocess.check_output([getenv("CC", 'clang'), '-c', '-x', 'c', *args, *arch_args, '-', '-o', '-'], input=src.encode('utf-8'))
#      26 return jit_loader(obj)
#
# File ~/.pyenv/versions/3.13.7/lib/python3.13/subprocess.py:472, in check_output(timeout, *popenargs, **kwargs)
#     469         empty = b''
#     470     kwargs['input'] = empty
# --> 472 return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     473            **kwargs).stdout
#
# File ~/.pyenv/versions/3.13.7/lib/python3.13/subprocess.py:554, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     551     kwargs['stdout'] = PIPE
#     552     kwargs['stderr'] = PIPE
# --> 554 with Popen(*popenargs, **kwargs) as process:
#     555     try:
#     556         stdout, stderr = process.communicate(input, timeout=timeout)
#
# File ~/.pyenv/versions/3.13.7/lib/python3.13/subprocess.py:1039, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1035         if self.text_mode:
#    1036             self.stderr = io.TextIOWrapper(self.stderr,
#    1037                     encoding=encoding, errors=errors)
# -> 1039     self._execute_child(args, executable, preexec_fn, close_fds,
#    1040                         pass_fds, cwd, env,
#    1041                         startupinfo, creationflags, shell,
#    1042                         p2cread, p2cwrite,
#    1043                         c2pread, c2pwrite,
#    1044                         errread, errwrite,
#    1045                         restore_signals,
#    1046                         gid, gids, uid, umask,
#    1047                         start_new_session, process_group)
#    1048 except:
#    1049     # Cleanup if the child failed starting.
#    1050     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File ~/.pyenv/versions/3.13.7/lib/python3.13/subprocess.py:1972, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session, process_group)
#    1970     err_msg = os.strerror(errno_num)
#    1971 if err_filename is not None:
# -> 1972     raise child_exception_type(errno_num, err_msg, err_filename)
#    1973 else:
#    1974     raise child_exception_type(errno_num, err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'clang'
